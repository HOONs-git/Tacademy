# %% [markdown]
# # 웹 프로그래밍

# %%
def sosort(arr):
  #arr_sosort = sorted(arr)
#  arr_sosor t= arr.sort()
  arr.sort()
  #return arr_sosort
  return arr
print( sosort( [-5,1,2,3,4] ) )
# Out:
# [-5, 1, 2, 3, 4]

# %% [markdown]
# - s/w or 프로그램 or 언어구성
#   - 프론트엔드
#     - 웹 브라우저에서 보이는 **화면 담당**
#     - 구성
#       - html
#         - 뼈대, 컨텐츠
#       - css
#         - 디자인, 레이아웃, 애니메이션
#       - `javascript`
#         - 문법 난이도
#           - 초~중 : js (자바스크립트)
#           - 중~고 : ts (타입스크립트)
#         - 사용자와 브라우저(프론트가 보이는 s/w)에 표현된 프론트엔드 화면간 인터렉션(상호작용)
#           - 이벤트, 통신, 동적화면구성
#         - `js를 통해서 대시보드를 인터렉티브하게 구성 목표`
#   - 백엔드
#     - **프론트엔드 화면 구성에 필요한 서비스, 비즈니스로직, 디비쿼리 등 업무 수행, 프론트화면에 결과를 전송**
#     - 프론트엔드 파트에서 만들어지는 화면 동적 구성하여 제공, 데이터 제공하는 역할
#     - 언어/프레임웍
#       - java - springboot(oracle 베이스)
#         - servlet/jsp >> ejb >> spring >> springboot
#       - c# - .net(닷넷, MS(마이크로소프트) )
#         - asp >> .net
#       - php - php(apache + php + mysql : 리눅스)
#       - javascript/typescript - nodejs(구글 2000 전후 검색엔진 = 2005 구글지도(ajax 개발) - 2008 전후 크롬브라우저(v8 엔진기반) - 2009 전후 nodejs 탄생(구글x, v8엔진기반)
#         - 프론트부터 백엔까지 단일언어(js를 사용) 개발 가능해짐
#       - python - flask, django, fastapi
#         - 빅데이터분석, 데이터처리, ai등에 주력 언어 파이썬임 >> ai시대에 웹서비스까지 단일언어로 구성 가능 조합 (node >> flask, django, fastapi) 흐름이 등장, fastapi는 LLM과 성능적 퍼포먼스로 각광을 받고있음
#       - ..
#   - 데이터베이스
#     - mysql

# %% [markdown]
# # Javascript

# %% [markdown]
# - 특징
#   - 세계top 10(선호도 높은) 언어 포함됨
#     - python도 포함됨
#   - SPA(Single Page Application) 개발시 주력언어
#     - 1개의 페이지에서 클릭 등 이벤트를 통해 다른 화면이 나올떄 기존 내용을 지우고 새로 렌더링 >> 화면 깜빡임( 주소창 옆에 x표기 >> 없음)
#     - Angular - 구글
#     - react - 메타 (1위)
#     - vue - 커뮤니티 (2위)
#     - ...
# - History
#   - 2005년 구글 지도이후 js, ajax는 프론트엔드의 핵심 기술로 정립
#   - 2009~2010 : nodejs 등장으로 js는 백엔드 분야로 확장
#   - 현재
#     - 프론트엔드, 백엔드
#     - 웹, 앱, 데스크톱, app 모두 개발 가능
# - 버전
#   - 관리 : `ECMA` Script (Java Script 공식 명칭)
#     - www.w3schools.com
#       - HTML, CSS, JS등 표준 안내, 학습 제공
#     - 2009 :ES5(ECMA Script 5) 표준의 기본
#       - 모든 브라우저에 공통으로 적용
#     - 2015 : ES6( ECMA Script 2015, ECMA2015)
#       - 현재 표준의 기본형태 `ES Next`
#       - 현재 사용하는 대부분의 추가 문법들이 이떄 적립됨
#     - 이후 : 매년 갱신(문법)
# - 구동 특징
#   - 최신문법 적용 >> **babel** >> ES Next or ES5로 변환하여 구동
#   - babel : 최신 코드를 호환 코드로 전환
#   - LLM이 만드는 코드 >> ES Next(ES6) or ES5
#     - **현재 표준은 ES6(ES Next)**
#
# - typescript
#   - ES5 공부 >> ES6 공부 >> TS 공부
#   - TS 구동
#     - TS >> ES6(ES Next) 구동 >> ES5 변환구동
#   - javascript + type + 약간의 문법

# %% [markdown]
# # 개발환경

# %% [markdown]
# - IDE (개발 통합 환경)
#   - vs code 사용
#     - https://code.visualstudio.com/
#   - ... (어떤 툴이던 가능)

# %% [markdown]
# - **nodejs 설치**
#   - js를 프로그램적으로 개발하기 위해 설치
#   - node 기반
#     - js 문법 습득등 단독 구동 가능
#     - 설치
#       - os단 직접 설치
#         - https://nodejs.org/ko
#       - docker의 컨테이너로 설치
#
# - nodejs 미사용 js 구동
#   - 브라우저의 개발자모드 > 콘솔 화면 직접 구동

# %% [markdown]
# - 도커에 컨테이너로 node.js 설치
#   - 호스트PC의 ~\projects\node 와 컨테이너의 /home/js 경로가 서로 공유하여 파일(*.JS)이 위치됨
# ```
# docker run --name node -p 3000:3000 -itd -v C:\Users\Dell3571\Desktop\projects\node:/home/js node
# ```
#
# ```
# # 호스트ps
# C:\Users\Dell5371>docker exec -it node bash
# root@86c329e55501:/#
# root@86c329e55501:/# node -v
# v25.0.0
# root@86c329e55501:/# node
# Welcome to Node.js v25.0.0.
# Type ".help" for more information.
# > console.log("helloworld");
# helloworld
# undefined
# >
# (To exit, press Ctrl+C again or Ctrl+D or type .exit)
# >
# root@86c329e55501:/# exit
# exit
#
# C:\Users\Dell5371>
# ```

# %% [markdown]
# - VSCODE 구동
#   - dev containers 설치
#   - F1 (+Fn) or Ctrl + Shift + p 실행
#     - 명령 팔레트 구동
#     - dev containers:Attach to Runngin Container... 실행
#     - 구동중인 컨테이너 목록 표현
#       ```
#         - mysql
#         - node << 선택
#       ```
#     - 새창(vs code) 오픈(최초)
#       - 왼쪽 메뉴 explorer 오픈
#       - open folder
#         - /root/ >> /home/js 선택 >>ok

# %% [markdown]
# - 결론
#   - node는 컨테이너로 존재
#     - 구동 후 사용
#   - vscode를 통해서 간편하게 컨테이너에 존재하는 소스코드(혹은 직접 작성하는 코드)를 개발 실행 가능함
#   - 최종 결과물 `~/projects/node/~` 하위에 공유됨(실시간) << 호스트 OS(PC, 윈도우, 맥)

# %% [markdown]
# # 파이썬 설치(docker 기반)

# %% [markdown]
# ```
# docker run --name python -p 8000:8000 -itd -v C:\Users\Dell3571\Desktop\projects\python:/home/app python
# ```

# %% [markdown]
# # 목차

# %% [markdown]
# - 변수, 주석...
# - 문자열
# - 연산자
# - 형변환
# - 흐름제어
# - 함수
# - 배열
# - 클래스, 객체 <-> json 대응
# - 주요 최신문법(ES6 이후)
