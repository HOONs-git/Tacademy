# %% [markdown]
# # 개요

# %% [markdown]
# - 파이썬 프로그램 구성
#   - 모듈 <-> *.ipynb(노트북파일, 분석|학습용)
#     - *.py
#     - 파이썬 파일
#       ```
#         # 실행
#         python *.py
#       ```
#   - 패키지
#     - 디렉토리(폴더)
#     - 디렉토리 내부에는 여러개의 *.py, 또 다른 패키지 존재
#     - 패키지는 같은 목적을 가진 모듈등이 모여있는 구조
#   - 리소스
#     - 파일(환경변수, 이미지, 미디어....)

# %% [markdown]
# # 모듈화/패키지

# %% [markdown]
# - 팀 작업 >> 작업 자체가 분업(각자 산출물 존재)
#   - 작업 공유(다른 사람이 만든 모듈을 내가 사용해야 되는 상황)
#   - 이를 위해 작성된 코드는 모듈화 되어야함
# - 연습 구조 (왼쪽 목차밑에 파일에 밑에 설명과 같은 구조로 a,b .py파일 만들었다)
# ```
#   / : 루트
#   6.모듈화_모듈가져오기_예외처리_.ipynb : 현재 파일
#   a : 디렉토리
#    L b :디렉토리
#      L __init__.py : b 패키지 대변하는 모듈
#      L mod.py : 모듈
#    L __init__.py : a 패키지 대변
# ```

# %% [markdown]
# - 파일구성
#   a > ```__init.py```
#     ```
#     PI = 3.14
#     ```
#   a > b > ```__init.py```
#     ```
#     PI2 = 3.144
#     ```
#   a > b > ```mod.py```
#   ```
#   # mod
#   # 변수(상수 용도임)
#   PI3 = 3.1456789
#
#   #함수
#   def add(x,y):
#   return x + y
#
#   #클래스
#   class A: pass
#   ```

# %% [markdown]
# - 1번유형
#   ```
#     from ~ import ~
#
#     from 패키지.패키지.패키지.....모듈 import 변수|함수|클래스|*(모든것)
#
#     from 패키지.패키지.패키지.....패키지 import 변수|함수|클래스|*(모든것)
#
#     from 모듈|패키지 import 변수|함수|클래스|*(모든것)
#
#     경로법은 반드시 프로그램이 시작되는 엔트리포인트 파일을 기준으로 절대경로로 계산
#   ```
# - 2번 유형
#   ```
#   import ~
#
#   import 패키지.패키지.패키지.....모듈
#   import 패키지.패키지.패키지.....패키지
#   import 모듈|패키지
#   - 공통 (통상 별칭을 자주 사용함)
#     -import .... as 별칭
#   ```

# %%
# 1번유형 >> 다른 모듈, 패키지에 존재하는 변수, 함수 , 클래스 가져오기
from a.b.mod import PI3, add, A
# 원래 내가 만든 자원으로 이해하고 사용
PI3, add(1,3), A()
# Out:
# (3.1456789, 4, <a.b.mod.A at 0x7f8dfc431e20>)

# %%
'''
  패키지를 인식하게 하려면 디렉토리 내부에 __init__.py 파일이 있어야 한다.
'''
from a.b import PI2

PI2
# Out:
# 3.144

# %%
# *(와일드카드) 해당 모듈의 모든 자원을 가져오기함(일일이 가져오기에는 너무 많다)
from a import *

PI
# Out:
# 3.14

# %%
# 2번유형
import a.b.mod

a.b.mod.PI3
# Out:
# 3.1456789

# %%
# 사용시 경로가 너무 길다 >> 별칭 부여
import a.b.mod as m

a.b.mod.PI3, m.PI3
# Out:
# (3.1456789, 3.1456789)

# %%
import pandas as pd
import numpy as np

# %%
import a.b as my
my.PI2
# Out:
# 3.144

# %% [markdown]
# # 모듈가져오기

# %% [markdown]
# # ```__name__```

# %% [markdown]
# - 사용 위치에 따라 2가지로 해석(동적)
#   - 사전에 정의된 파이썬의 전역변수
# - 유형 1
#   - __name__을 사용한 모듈을 직접 실행한다면
#   ```
#     "__main__"
#   ```

# %%
__name__
# Out:
# '__main__'

# %% [markdown]
# - 유형2
#   - '__name__' 이 기술된 모듈(xx+py)을 다른 모듈(혹은 노트)에서 사용한다면
#     ```
#       "패키지.파일명"
#     ```

# %%
import a.test
# Out:
# __name__ 출력값 a.test

# %% [markdown]
# ```
# # support.py
# # A 개발자는 support.py를 제작 하였다
# # 전체 프로젝트의 한파트를 담당했다
# # A 개발자는 단위테스트등 진행.
# # 전체 개발 모듈을 조립하는 메인 코더에게 전달했다(git)
# def t(x,y):
#   print(x+y)
#
# # 단위테스트 >> 메인코더가 사용할떄 작동X
# if __name__ == '__main__':
#   t(1,2)
# ```

# %%
# support.py 파일을 가져와서 사용하는 개발자 화면
import a.support

# %% [markdown]
# - 결론
#   - 모듈을 만드는 모든 사람은 해당 모듈의 테스트코드 등을 수행할때 반드시 아래 코드에서 진행(단, 테스트 코드도 본 코드에 포함한다면)
#   ```
#     if __name__ == '__main__'
#       # 테스트코드
#   ```
#   - 모든 서비스의 엔트리포인트(진입로, 시작코드)는 아래처럼 표현
#     ```
#     if __name__ == '__main__'
#       # 어플리케이션 시작코드는 아래처럼 표현
#           ```
#               if __name__ == '__main__'
#                     # 어플리케이션 시작코드

# %% [markdown]
# # 예외처리

# %% [markdown]
# - 파이썬 진영 처리 루틴
#   - https://peps.python.org/pep-0463/

# %% [markdown]
# - 개요
#   - 프로그램은 셧다운 되면 x
#   - 잠재된 오류 상황에 대한 처리
#     - 꼼꼼하게 테스트후 체크
#       - 조건문이 아주 많이 사용됨
#       - LBYL : Look Before You Leap
#         - 에러가 나올만한 상황을 꼼꼼하게 체크하여 코드를 구성
#
#     - 진행 >> 오류발생 >> 처리
#       - 코드를 계속 진행. 수습은 나중에(개발단계)
#       - EAFP : Easier to Ask for Forgiveness than Permission
#         - 파이썬은 이 방식을 권장함 >> 코드가 간결해짐 >> 회사내 문화 참고
#         - **예외처리**
#           - 오류를 책임지고 잡아서 처리
#             ```
#               try ~ except ~ else ~ finally ~
#               try ~ except ~ finally ~
#               try ~ except ~
#               try ~ except ~ else
#             ```
#           - 오류 던지기
#             - 한곳에서 오류를 일괄 처리한다
#               ```
#                 raise
#               ```

# %% [markdown]
# - 문법
#   -예외 처리문
# ```
# try:
#   # 예외상황이 나올만한(의심스러운)코드
#   # I/O
# except 오류객체명1:
#   # 오류처리(로그기록, 등등)
# except 오류객체명1:
#   # 오류처리(로그기록, 등등)
# ...
#
# [else:] #생략가능
#   # 오류가 없으면 진입함
#   # 이런 상황을 알고 싶다면 사용
#
# [finally:] #생략가능
#   # 뒷정리 코드
#   # 오류가 발생/정상 관계없이 진입
# ```
#
# - 오류객체
#   - 최상위 객체(모든 오류의 근본, 루트) >> Exception

# %%
# 예외처리문 작성 >> 정상케이스
try:
  print(1)
except Exception as e:
  print('예외발생', e)
else:
  print('정상, 오류없음')
finally:
  print('뒷정리')
# Out:
# 1
# 정상, 오류없음
# 뒷정리

# %%
# 예외처리문 작성 >> 오류케이스
try:
  print(1)
  print(1/0) # 오류발생 0으로 나누기해서
  print(2) # 수행 X
except Exception as e:
  print('예외발생', e)
else:
  print('정상, 오류없음')
finally:
  print('뒷정리')
# Out:
# 1
# 예외발생 division by zero
# 뒷정리

# %%
# 오류 던지기
def except_call():
  try:
    1/0
  except Exception as e:
    raise e # 오류 던지기 >> 상위 레벨로 전달

try:
  # 함수 내부에서 오류 발생함(하위 레벨에서 오류 발생)
  except_call()
except Exception as e:
  print('오류처리', e)
# Out:
# 오류처리 division by zero
